# %% [markdown]
# Загрузка и первичный анализ данных

# %%
import pandas as pd

df = pd.read_json('raw_data_20k.json')

# %%
print(df.columns, '\n')
print(df['text'][0], '\n')
for ent in df['entities'][0]:
    print(ent)
# Out:
# Index(['id', 'language', 'text', 'entities'], dtype='object')
#
# **Deportation Notice**
#
# **Ministry of Interior: Department of Immigration and Deportations**
# **Government of Spain**
#
# **Notice No.: 312-5589-0289**
# **Date Issued: October 17, 2023**
#
# ---
#
# **To:**
# Tatiana Leon-Palmer
# Pasaje de Efraín Barral 78,
# Santa Cruz de Tenerife, 50091
# **Identification Number:** ES-92-205788-LP
#
# **Subject: Official Notice of Deportation**
#
# Dear Ms. Tatiana Leon-Palmer,
#
# This document serves as an official notification of your impending deportation from the Kingdom of Spain pursuant to Section 24, Subsection 5 of the Spanish Immigration Law. After a thorough review of your case and subsequent legal proceedings, it has been determined that your continued residence in Spain no longer complies with the legal standards set forth by the national immigration policy.
#
# **Circumstances Leading to Deportation:**
#
# - **Violation of Visa Terms:** It is found that you have exceeded the duration of stay permitted under your work visa issued on January 21, 2021. This violation was noted during a routine check by immigration enforcement officers on June 9, 2023.
#
# - **Employment without Proper Authorization:** Investigations have revealed that you have been engaged in unauthorized employment at Pedrero y Cerdá S.L.L., an entity not listed on your work permit.
#
# As a consequence of these violations, and in accordance with immigration law, your legal status in Spain has been revoked effective immediately. You are required to exit the Spanish territory no later than November 30, 2023. Failure to comply with this directive will result in compulsory enforcement actions.
#
# **Departure and Travel Arrangements:**
#
# You are instructed to contact the Deportation Coordination Office no later than November 10, 2023, to confirm your travel arrangements. The office is located at the following address:
#
# Duran y Pozuelo S.L.L.,
# Calle Ficticia 233,
# Alicante, 03003
#
# **Contact Information:**
# Phone: +34 965 124 5879
# Email: deport-coord@dyp.es
#
# **Legal Rights and Appeals Process:**
#
# You have the right to appeal this deportation order within twenty-one (21) days from the date of this notice. Should you decide to file an appeal, it must be directed to the National Immigration Tribunal located at:
#
# Tribunal Nacional de Migración,
# Avenida de la Constitución 44,
# 50091 Zaragoza
#
# It is imperative that any appeal submission includes your case number (312-5589-0289) and a detailed justification for reconsideration. The appeal must be submitted in written form and received by the tribunal no later than November 7, 2023.
#
# **Additional Information:**
#
# Please be aware that non-compliance with this deportation order may result in further legal consequences, including but not limited to detention and a permanent ban on re-entry to Spain and other Schengen Area countries. We urge you to take immediate steps to comply with this notice and ensure your departure from Spain by the stipulated date.
#
# For further inquiries or assistance regarding this matter, you may contact Vidal Onofre Santana Pablo, your assigned case officer, at +34 965 124 5879 or via email at vos-pablo@interior.es.
#
# We regret any inconvenience this may cause and thank you in advance for your cooperation in maintaining the integrity of Spanish immigration policies.
#
# **Sincerely,**
#
# **Catalina Gallardo**
# **Director, Department of Immigration and Deportations**
# **Ministry of Interior, Government of Spain**
#
# ---
#
# Page 1 of 2 | Next Page
#
# {'text': '50091', 'type': 'ADDRESS'}
# {'text': 'Tatiana Leon-Palmer', 'type': 'PERSON'}
# {'text': 'Santa Cruz de Tenerife', 'type': 'LOCATION'}
# {'text': 'ES-92-205788-LP', 'type': 'ID_NUMBER'}
# {'text': 'January 21, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'June 9, 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Pasaje de Efraín Barral 78', 'type': 'ADDRESS'}
# {'text': 'Pedrero y Cerdá S.L.L.', 'type': 'ORGANIZATION'}
# {'text': 'November 30, 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'November 10, 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Duran y Pozuelo S.L.L.', 'type': 'ORGANIZATION'}
# {'text': 'Calle Ficticia 233', 'type': 'ADDRESS'}
# {'text': 'Alicante', 'type': 'LOCATION'}
# {'text': '03003', 'type': 'ADDRESS'}
# {'text': '+34 965 124 5879', 'type': 'CONTACT_INFO'}
# {'text': 'deport-coord@dyp.es', 'type': 'CONTACT_INFO'}
# {'text': 'National Immigration Tribunal', 'type': 'ORGANIZATION'}
# {'text': 'Avenida de la Constitución 44', 'type': 'ADDRESS'}
# {'text': '50091 Zaragoza', 'type': 'ADDRESS'}
# {'text': '312-5589-0289', 'type': 'ID_NUMBER'}
# {'text': 'November 7, 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Vidal Onofre Santana Pablo', 'type': 'PERSON'}
# {'text': 'vos-pablo@interior.es', 'type': 'CONTACT_INFO'}
# {'text': 'Catalina Gallardo', 'type': 'PERSON'}
# {'text': 'Department of Immigration and Deportations', 'type': 'ORGANIZATION'}
# {'text': 'October 17, 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Ministry of Interior, Government of Spain', 'type': 'ORGANIZATION'}

# %% [markdown]
# Рассчитаем статистику по типам определяемых сущностей

# %%
types_stat = dict()

for i, row in df.iterrows():
    for entity in row['entities']:
        types_stat[entity['type']] = types_stat.get(entity['type'], 0) + 1

print('Лейблы:')
print(*list(types_stat.keys()), sep='\n')
print('')
print('Количество лейблов: ', len(types_stat))
print('')
print(sorted(types_stat.items(), key=lambda tup: tup[1], reverse=True))

"""
matplotlib не работает после установки spacy
keys = list(types_stat.keys())
vals = [types_stat[k] for k in keys]
sns.barplot(x=keys, y=vals)
"""
# Out:
# Лейблы:
# ADDRESS
# PERSON
# LOCATION
# ID_NUMBER
# TEMPORAL_TIME_DATE
# ORGANIZATION
# CONTACT_INFO
# FINANCIAL
# NUMBER
# JOB_TITLE_OR_ROLE
# HEALTH
# PASSWORD_OR_KEY
# PROPRIETARY_TECHNOLOGY
# SERVER_IP_ADDRESS
# CODE_RELATED
# USERNAME
# BANK_OR_FINANCIAL_ACCOUNT
# PROFESSIONAL
# BUSINESS_STRATEGY
# MANUFACTURING_PROCESS
# UNIQUE_DESCRIPTOR
# MARKETING_STRATEGY
# RACIAL_ETHNIC
# TRADE_SECRET
# SEXUAL_ORIENTATION
# EDUCATION
# POLITICAL
# DEVICE_ID
# CURRENCY
# SCIENTIFIC_RESEARCH
# CRIMINAL
# COMMUNICATION
# RELIGIOUS
# BEHAVIORAL
#
# Количество лейблов:  34
#
# [('TEMPORAL_TIME_DATE', 103250), ('PERSON', 59305), ('ORGANIZATION', 54830), ('FINANCIAL', 42890), ('LOCATION', 36281), ('ADDRESS', 27572), ('NUMBER', 22906), ('ID_NUMBER', 22834), ('UNIQUE_DESCRIPTOR', 20633), ('CODE_RELATED', 20509), ('CONTACT_INFO', 17579), ('PROPRIETARY_TECHNOLOGY', 17539), ('JOB_TITLE_OR_ROLE', 16046), ('BANK_OR_FINANCIAL_ACCOUNT', 10019), ('PASSWORD_OR_KEY', 6262), ('EDUCATION', 5811), ('BUSINESS_STRATEGY', 5343), ('HEALTH', 5250), ('SERVER_IP_ADDRESS', 4182), ('MARKETING_STRATEGY', 1980), ('PROFESSIONAL', 1885), ('TRADE_SECRET', 1417), ('SCIENTIFIC_RESEARCH', 1221), ('DEVICE_ID', 1126), ('CRIMINAL', 969), ('USERNAME', 884), ('RACIAL_ETHNIC', 651), ('MANUFACTURING_PROCESS', 565), ('CURRENCY', 471), ('COMMUNICATION', 328), ('POLITICAL', 181), ('RELIGIOUS', 152), ('SEXUAL_ORIENTATION', 148), ('BEHAVIORAL', 116)]
# 'brkn\nkeys = list(types_stat.keys())\nvals = [types_stat[k] for k in keys]\nsns.barplot(x=keys, y=vals)\n'

# %%
import spacy

nlp = spacy.load("en_core_web_sm", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])
print(*zip(nlp.pipe_labels['ner'], map(spacy.explain, nlp.pipe_labels['ner'])), sep='\n')
print(len(nlp.pipe_labels['ner']))
# Out:
# ('CARDINAL', 'Numerals that do not fall under another type')
# ('DATE', 'Absolute or relative dates or periods')
# ('EVENT', 'Named hurricanes, battles, wars, sports events, etc.')
# ('FAC', 'Buildings, airports, highways, bridges, etc.')
# ('GPE', 'Countries, cities, states')
# ('LANGUAGE', 'Any named language')
# ('LAW', 'Named documents made into laws.')
# ('LOC', 'Non-GPE locations, mountain ranges, bodies of water')
# ('MONEY', 'Monetary values, including unit')
# ('NORP', 'Nationalities or religious or political groups')
# ('ORDINAL', '"first", "second", etc.')
# ('ORG', 'Companies, agencies, institutions, etc.')
# ('PERCENT', 'Percentage, including "%"')
# ('PERSON', 'People, including fictional')
# ('PRODUCT', 'Objects, vehicles, foods, etc. (not services)')
# ('QUANTITY', 'Measurements, as of weight or distance')
# ('TIME', 'Times smaller than a day')
# ('WORK_OF_ART', 'Titles of books, songs, etc.')
# 18

# %% [markdown]
# NER компонента в модели содержит 18 типов сущностей, почти в 2 раза меньше. Сравнив их, можно заметить, что по смыслу совпадают лейблы для имён, мест, времени, валют, чисел. Далее будет необходимо привести лейблы из датасета в соответствие лейблам spacy, а также добавить новые правила и удалить некоторые старые

# %% [markdown]
# Проверим работу spacy на одном из текстов

# %%
from spacy import displacy

doc = nlp(df['text'][0])
for ent in doc.ents:
    print('Entity: ', ent.text, ent.label_, spacy.explain(ent.label_))

displacy.render(doc, style="ent")
# Out:
# Entity:  Department of Immigration ORG Companies, agencies, institutions, etc.
# Entity:  312-5589-0289 CARDINAL Numerals that do not fall under another type
# Entity:  October 17, 2023 DATE Absolute or relative dates or periods
# Entity:  Tatiana Leon-Palmer
# Pasaje de Efraín PERSON People, including fictional
# Entity:  Barral 78 DATE Absolute or relative dates or periods
# Entity:  Santa Cruz de Tenerife GPE Countries, cities, states
# Entity:  50091 DATE Absolute or relative dates or periods
# Entity:  Tatiana Leon-Palmer PERSON People, including fictional
# Entity:  the Kingdom of Spain GPE Countries, cities, states
# Entity:  Section 24 LAW Named documents made into laws.
# Entity:  Subsection 5 DATE Absolute or relative dates or periods
# Entity:  Spain GPE Countries, cities, states
# Entity:  January 21, 2021 DATE Absolute or relative dates or periods
# Entity:  June 9, 2023 DATE Absolute or relative dates or periods
# Entity:  Pedrero y Cerdá S.L.L. ORG Companies, agencies, institutions, etc.
# Entity:  Spain GPE Countries, cities, states
# Entity:  Spanish NORP Nationalities or religious or political groups
# Entity:  2023 DATE Absolute or relative dates or periods
# Entity:  the Deportation Coordination Office ORG Companies, agencies, institutions, etc.
# Entity:  2023 DATE Absolute or relative dates or periods
# Entity:  Duran GPE Countries, cities, states
# Entity:  Pozuelo GPE Countries, cities, states
# Entity:  S.L.L. ORG Companies, agencies, institutions, etc.
# Entity:  Calle Ficticia 233 PERSON People, including fictional
# Entity:  03003 DATE Absolute or relative dates or periods
# Entity:  965 124 CARDINAL Numerals that do not fall under another type
# Entity:  5879 DATE Absolute or relative dates or periods
# Entity:  twenty-one CARDINAL Numerals that do not fall under another type
# Entity:  21) days DATE Absolute or relative dates or periods
# Entity:  the National Immigration Tribunal ORG Companies, agencies, institutions, etc.
# Entity:  Avenida de la Constitución PERSON People, including fictional
# Entity:  312-5589-0289 DATE Absolute or relative dates or periods
# Entity:  2023 DATE Absolute or relative dates or periods
# Entity:  Spain GPE Countries, cities, states
# Entity:  Schengen Area ORG Companies, agencies, institutions, etc.
# Entity:  Spain GPE Countries, cities, states
# Entity:  Vidal Onofre Santana Pablo PERSON People, including fictional
# Entity:  5879 DATE Absolute or relative dates or periods
# Entity:  Spanish NORP Nationalities or religious or political groups
# Entity:  Department of Immigration and Deportations* ORG Companies, agencies, institutions, etc.
# Entity:  1 CARDINAL Numerals that do not fall under another type
# Entity:  2 CARDINAL Numerals that do not fall under another type
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">**Deportation Notice**<br><br>**Ministry of Interior:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Department of Immigration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Deportations**  <br>**Government of Spain**<br><br>**Notice No.:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     312-5589-0289
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# **  <br>**Date Issued:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 17, 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **<br><br>---<br><br>**To:**  <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tatiana Leon-Palmer
# Pasaje de Efraín
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barral 78
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,  <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santa Cruz de Tenerife
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50091
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   <br>**Identification Number:** ES-92-205788-LP<br><br>**Subject: Official Notice of Deportation**<br><br>Dear Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tatiana Leon-Palmer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,<br><br>This document serves as an official notification of your impending deportation from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Kingdom of Spain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  pursuant to
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Section 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subsection 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the Spanish Immigration Law. After a thorough review of your case and subsequent legal proceedings, it has been determined that your continued residence in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  no longer complies with the legal standards set forth by the national immigration policy.<br><br>**Circumstances Leading to Deportation:**<br><br>- **Violation of Visa Terms:** It is found that you have exceeded the duration of stay permitted under your work visa issued on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 21, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . This violation was noted during a routine check by immigration enforcement officers on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 9, 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br>  <br>- **Employment without Proper Authorization:** Investigations have revealed that you have been engaged in unauthorized employment at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pedrero y Cerdá S.L.L.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , an entity not listed on your work permit.<br><br>As a consequence of these violations, and in accordance with immigration law, your legal status in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been revoked effective immediately. You are required to exit the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  territory no later than November 30,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Failure to comply with this directive will result in compulsory enforcement actions.<br><br>**Departure and Travel Arrangements:**<br><br>You are instructed to contact
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Deportation Coordination Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  no later than November 10,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , to confirm your travel arrangements. The office is located at the following address:<br><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; mar

# %% [markdown]
# Сразу видны проблемы с лейблами ID_NUMBER, ADDRESS, CONTACT_INFO. Hаиболее распространенный лейбл TEMPORAL_TIME_DATE не всегда
# определяется верно из-за пересечения с контактными данными и из-за запятой после месяца. Стоит проверить тексты из датасета с другими лейблами

# %%
labels_to_check = {'UNIQUE_DESCRIPTOR', 'CODE_RELATED', 'CONTACT_INFO', 'PROPRIETARY_TECHNOLOGY', 'JOB_TITLE_OR_ROLE', 'BANK_OR_FINANCIAL_ACCOUNT', 'PASSWORD_OR_KEY', 'EDUCATION', 'BUSINESS_STRATEGY', 'HEALTH', 'SERVER_IP_ADDRESS', 'MARKETING_STRATEGY', 'PROFESSIONAL', 'TRADE_SECRET', 'SCIENTIFIC_RESEARCH', 'DEVICE_ID', 'CRIMINAL', 'USERNAME', 'RACIAL_ETHNIC', 'MANUFACTURING_PROCESS', 'CURRENCY', 'COMMUNICATION', 'POLITICAL', 'RELIGIOUS', 'SEXUAL_ORIENTATION', 'BEHAVIORAL'}
samples = []

for i, row in df.iterrows():
    row_labs = {ent['type'] for ent in row['entities']}
    if labels_to_check & row_labs:
        samples.append(row)
        labels_to_check -= row_labs

print(f'{len(samples)} samples to check')
# Out:
# 15 samples to check

# %% [markdown]
# Рассмотрим некоторые из примеров

# %%
def show_sample(i):
    if i > len(samples): return
    print(*samples[i]['entities'], sep='\n')
    doc = nlp(samples[i]['text'])
    displacy.render(doc, style="ent")

show_sample(1)
# Out:
# {'text': '44-492-8374', 'type': 'ID_NUMBER'}
# {'text': '(02) 9375 2431', 'type': 'CONTACT_INFO'}
# {'text': 'Coleman and Long Pty Ltd.', 'type': 'ORGANIZATION'}
# {'text': 'Level 31, 200 George Street, Sydney, NSW 2000', 'type': 'ADDRESS'}
# {'text': 'Stephen Wyatt', 'type': 'PERSON'}
# {'text': '(03) 9475 6678', 'type': 'CONTACT_INFO'}
# {'text': '58 Arden Street, North Melbourne, VIC 3051', 'type': 'ADDRESS'}
# {'text': 'Twenty-fourth of July, Two Thousand and Twenty-Three', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Twenty-fourth of July, Two Thousand and Twenty-Eight', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Three Hundred Thousand Australian Dollars', 'type': 'FINANCIAL'}
# {'text': 'AUD 300,000', 'type': 'FINANCIAL'}
# {'text': 'seven percent', 'type': 'NUMBER'}
# {'text': '7%', 'type': 'NUMBER'}
# {'text': 'July Twenty-fourth, Two Thousand and Twenty-Three', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'July Twenty-fourth, Two Thousand and Twenty-Eight', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'seven percent', 'type': 'NUMBER'}
# {'text': '7%', 'type': 'NUMBER'}
# {'text': 'five percent', 'type': 'NUMBER'}
# {'text': 'July Twenty-fourth, Two Thousand and Twenty-Three', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': '365-day year', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': '5%', 'type': 'NUMBER'}
# {'text': 'State of New South Wales', 'type': 'LOCATION'}
# {'text': 'Laura Velez', 'type': 'PERSON'}
# {'text': '24th July 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Director', 'type': 'JOB_TITLE_OR_ROLE'}
# {'text': 'Stephen Wyatt', 'type': 'PERSON'}
# {'text': 'Debra Prince', 'type': 'PERSON'}
# {'text': '24th July 2023', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': '102 High Street, Preston, VIC 3072', 'type': 'ADDRESS'}
# {'text': '24th July 2023', 'type': 'TEMPORAL_TIME_DATE'}
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">**Promissory Note**<br><br>**Lender:** Coleman and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Long Pty Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#    <br>**ABN:**
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44-492-8374
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#   <br>**Address:** Level 31,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sydney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NSW 2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   <br>**Telephone:** (02)
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9375
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  2431  <br><br>**Borrower:**
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Wyatt
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# **Address:**
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     58
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arden Street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Melbourne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , VIC 3051  <br>**Telephone:** (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     03) 9475 6678
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   <br><br>**Date of Issue:**
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twenty-fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two Thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and Twenty-Three  <br>**Due Date:**
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twenty-fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two Thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and Twenty-Eight  <br><br>**Principal Amount:**
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three Hundred Thousand Australian Dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (AUD
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# )  <br><br>**Terms and Conditions:**<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Promise to Pay:**  <br>   Under this Promissory Note,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Wyatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (hereinafter referred to as the &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Borrower
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;), promises to pay
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coleman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity"

# %% [markdown]
# Здесь видно, что лейбл FINANCIAL в датасете соответствует MONEY в spacy. AUD 300 ошибочно было принято за CARDINAL. NUMBER соответствует PERCENT

# %%
show_sample(3)
# Out:
# {'text': 'Dr. William McKenzie', 'type': 'PERSON'}
# {'text': 'Toronto Software Solutions, Inc.', 'type': 'ORGANIZATION'}
# {'text': 'Canada', 'type': 'LOCATION'}
# {'text': 'October 10, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Dr. Emily Robertson', 'type': 'PERSON'}
# {'text': 'August 15, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'dbserver.domain.com', 'type': 'SERVER_IP_ADDRESS'}
# {'text': 'salesdb', 'type': 'CODE_RELATED'}
# {'text': 'dbadmin', 'type': 'USERNAME'}
# {'text': 'N3wP@ss2021!', 'type': 'PASSWORD_OR_KEY'}
# {'text': 'Mr. Michael Johnson', 'type': 'PERSON'}
# {'text': 'September 20, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'https://api.example.com/data', 'type': 'SERVER_IP_ADDRESS'}
# {'text': 'AIzaSyB-4C3x2RQ8fL9nYD27QxTiO_jI4WzG6E0', 'type': 'PASSWORD_OR_KEY'}
# {'text': 'Toronto Software Solutions, Inc.', 'type': 'ORGANIZATION'}
# {'text': 'October 20, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'TS20211010CP', 'type': 'ID_NUMBER'}
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">**Document Title: Implementation of Secure Software Code Snippets in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# **<br><br>**Author: Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William McKenzie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# **<br>**Institution: Toronto Software Solutions, Inc.**<br>**Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 10, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **<br><br>---<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ###
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Abstract:<br>This document provides a detailed overview of secure coding practices using
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++ in the development of software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  systems. It includes specific code snippets, configuration settings, and the use of environment variables focused on enhancing security and performance. The examples given adhere to the latest industry standards as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and are tailored for developers operating within the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  software development landscape.<br><br>---<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ###
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Introduction:<br>In the rapidly evolving tech industry, ensuring code security and efficiency is paramount. This document presents a collection of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  code snippets that incorporate robust security features, such as encryption keys and secure
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  integrations. The snippets are designed for implementation in a variety of business applications across
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , ranging from finance to healthcare systems.<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ### Code Example 1:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Secure Database Connection<br>**Author: Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emily Robertson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# **<br>**Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 15, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **<br><br>```cpp<br>#include &lt;iostream&gt;<br>#include &lt;pqxx/pqxx&gt;  <br><br>void
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     connectDB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# () {<br>    const std::string CONNECTION_STR = &quot;dbname = salesdb host = dbserver.domain.com user = dbadmin password = N3wP@ss2021!&quot;;<br>    try {<br>        pqxx::connection
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C(CONNECTION_STR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# );<br>        if (C.is_open()) {<br>            std::cout &lt;&lt; &quot;Opened database successfully: &quot; &lt;&lt; C.dbname() &lt;&lt; std::endl;<br>        } else {<br>            std::cout &lt;&lt; &quot;Can't open database&quot; &lt;&lt; std::endl;<br>        }<br>    } catch (const std::exception &amp;e) {<br>        std::cerr &lt;&lt; e.what() &lt;&lt; std::endl;<br>    }<br>}<br>```<br>*Note: The password ‘N3wP@ss2021!’ is a placeholder and should be replaced with a secure, dynamically generated password in a production environment.*<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ### Code Example 2:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Secure API Request<br>**Author: Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Johnson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# **<br>**Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 20, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **<br><br>```cpp<br>#include &lt;curl/curl.h&gt;<br><br>void sendSecureRequest() {<br>    CURL *curl;<br>
# <mark class="entity"

# %% [markdown]
# Здесь видно, что дефолтные правила плохо справляются с кодом. Адрес апи был проигнорирован. ### почему-то принимаются за деньги

# %%
show_sample(7)
# Out:
# {'text': 'Luigina Flaiano', 'type': 'PERSON'}
# {'text': 'Piazza Zaccardo, 41', 'type': 'ADDRESS'}
# {'text': 'Ministry of Interior, Department for Civil Liberties and Immigration', 'type': 'ORGANIZATION'}
# {'text': 'September 14, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': '38056 Barco, Trento (TN)', 'type': 'ADDRESS'}
# {'text': 'Italy', 'type': 'LOCATION'}
# {'text': 'May 22, 1985', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Pontegrande, Italy', 'type': 'LOCATION'}
# {'text': 'IT985-5628-0417', 'type': 'ID_NUMBER'}
# {'text': '+39 0137 485962', 'type': 'CONTACT_INFO'}
# {'text': 'Location Manager', 'type': 'JOB_TITLE_OR_ROLE'}
# {'text': 'Heterosexual', 'type': 'SEXUAL_ORIENTATION'}
# {'text': 'Fingerprint ID 5875-LL9587', 'type': 'HEALTH'}
# {'text': 'University Degree in Film Studies', 'type': 'EDUCATION'}
# {'text': 'luigina.flaiano@mail.it', 'type': 'CONTACT_INFO'}
# {'text': 'University of Milan', 'type': 'EDUCATION'}
# {'text': '2007', 'type': 'EDUCATION'}
# {'text': 'Non-affiliated', 'type': 'POLITICAL'}
# {'text': 'August 10, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Pontegrande', 'type': 'LOCATION'}
# {'text': 'PI/4758962', 'type': 'ID_NUMBER'}
# {'text': 'PI/4950721', 'type': 'ID_NUMBER'}
# {'text': 'Dr. Giorgio Antonacci, MD', 'type': 'PERSON'}
# {'text': 'August 11, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Pontegrande Hospital', 'type': 'ORGANIZATION'}
# {'text': 'Gori, Chiaramonte e Antonacci e figli', 'type': 'ORGANIZATION'}
# {'text': '2015-2021', 'type': 'TEMPORAL_TIME_DATE'}
# {'text': 'Luigina Flaiano', 'type': 'PERSON'}
# {'text': 'September 14, 2021', 'type': 'TEMPORAL_TIME_DATE'}
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">**Document Number: IT/ASYL/092021-45**<br><br>**Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 14, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **<br><br>**Ministry of Interior,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Department for Civil Liberties and Immigration*
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# *  <br>**Request for Asylum – Urgent Processing**  <br>**Applicant:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Luigina Flaiano*
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# *<br><br>**Address:**  <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Piazza Zaccardo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     41
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#   <br>38056 Barco,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trento
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (TN)  <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br><br>---<br><br>**Part I: Personal Information**<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Full Name:** Luigina Flaiano<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Date of Birth:**
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 22, 1985
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Place of Birth:** Pontegrande,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **ID Number:** IT985-5628-0417<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Contact
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Info:**
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>   - **Email:** luigina.flaiano@mail.it<br>   - **Phone:** +39
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0137 485962
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Profession:** Location Manager<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Sexual Orientation:** Heterosexual<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Genetic Information:** Not Disclosed<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Biometric ID:** Fingerprint ID 5875-LL9587<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . **Education:**<br>    - **Level:** University Degree in Film Studies,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University of Milan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , completed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11

# %% [markdown]
# Похоже, лейблы CARDINAL и ORDINAL следует удалить, JOB_TITLE_OR_ROLE, EDUCATION добавить. Некоторые организации определяются не полностью, например 'Gori, Chiaramonte e Antonacci e figli' определилось без 'e figli'

# %% [markdown]
# Пользуясь наблюдениями, установим соответствие между лейблами в spacy и в датасете

# %%
def fix_labels(df):

    equivalences = {'LOCATION': 'GPE', 'TEMPORAL_TIME_DATE': 'DATE', 'ORGANIZATION': 'ORG', 'NUMBER': 'PERCENT'}
    
    def process_row(row):

        for ent in row:
            ent['type'] = equivalences.get(ent['type'], ent['type'])
        
        return row
    
    df['entities'] = df['entities'].apply(process_row)
    
    return df

# %% [markdown]
# Для вычисления метрик качества распознавания сущностей необходимо написать отдельные функции

# %%
def ner_prec(result: list, ground_truth: list):
    """
    Сравнение результатов вида
    [{text: tag}, ...]
    """
    correct = len([entity for entity in result if entity in ground_truth])
    total_res = len(result)

    return correct/total_res

def ner_rec(result: list, ground_truth: list):

    correct = len([entity for entity in result if entity in ground_truth])
    total_ground = len(ground_truth)

    return correct/total_ground

def ner_F1(result: list, ground_truth: list):

    prec = ner_prec(result, ground_truth)
    rec = ner_rec(result, ground_truth)

    if prec == rec == 0: return 0
    
    return 2*(prec*rec)/(prec+rec)

# %% [markdown]
# Теперь можно проверить точность работы spacy без изменения правил. Лейблы, которых нет в датасете будут отсеяны

# %%
def test_performance(df, relevant_labels):
    """
    Расчет метрик и статистики
    """
    metrics = {'prec': [], 'rec': [], 'F1': []}
    label_stats = dict()
    clean_df = fix_labels(df)
    
    for i, row in clean_df.iterrows():
        results = []
        doc = nlp(row['text'])
        for ent in doc.ents:
            if ent.label_ in relevant_labels:
                results.append({'text': ent.text, 'type': ent.label_})
        correct_results = [entity for entity in results if entity in row['entities']]
        
        for res in correct_results:
            label_stats[res['type']] = label_stats.get(res['type'], 0) + 1
        
        metrics['prec'], metrics['rec'], metrics['F1'] = [ner_prec(results, row['entities']), ner_rec(results, row['entities']), ner_F1(results, row['entities'])]

    return metrics, label_stats

# %%
import numpy as np

relevant_labels = {'PERSON', 'GPE', 'DATE', 'ORG', 'PERCENT'}
met, stat = test_performance(df, relevant_labels)
print(f'avg precision: {np.average(met['prec'])}, recall: {np.average(met['rec'])}, F1: {np.average(met['F1'])}')
print(stat)
# Out:
# avg precision: 0.3103448275862069, recall: 0.5, F1: 0.3829787234042554
# {'DATE': 62688, 'GPE': 24954, 'PERSON': 47659, 'ORG': 37045, 'PERCENT': 11669}

# %% [markdown]
# Любопытно, что recall оказалась выше, чем precision. Это может говорить о том, что spacy выделяет больше сущностей, чем есть в датасете, даже с отсеиванием части лейблов. Частичное совпадение/неправильное выделение сущностей затрудняют визуализацию ошибок.
#
# Наиболее распространенные лейблы в датасете:
# ('TEMPORAL_TIME_DATE', 103250), ('PERSON', 59305), ('ORGANIZATION', 54830), ('FINANCIAL', 42890), ('LOCATION', 36281), ('ADDRESS', 27572), ('NUMBER', 22906)
# Правильные результаты работы модели:
# {'TEMPORAL_TIME_DATE': 62688, 'LOCATION': 24954, 'PERSON': 47659, 'ORGANIZATION': 37045, 'NUMBER': 11669}

# %% [markdown]
# Попробуем добавить новые правила для определения контактных данных

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'ner': {'assigns': ['doc.ents',
#     'token.ent_iob',
#     'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
#   'entity_ruler': {'assigns': ['doc.ents', 'token.ent_type', 'token.ent_iob'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False}},
#  'problems': {'ner': [], 'entity_ruler': []},
#  'attrs': {'doc.ents': {'assigns': ['ner', 'entity_ruler'], 'requires': []},
#   'token.ent_iob': {'assigns': ['ner', 'entity_ruler'], 'requires': []},
#   'token.ent_type': {'assigns': ['ner', 'entity_ruler'], 'requires': []}}}

# %%
nlp = spacy.load("en_core_web_sm", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

config = {
   "validate": True,
   "overwrite_ents": True,
}

ruler = nlp.add_pipe("entity_ruler", config=config, before='ner')

patterns = [{"label": "CONTACT_INFO", "pattern": [{'IS_LOWER': True, 'LIKE_EMAIL': True}]}]

ruler.add_patterns(patterns)

doc = nlp("vos-pablo@interior.es")

for ent in doc.ents:
    print('Entity: ', ent.text, ent.label_)

displacy.render(doc, style="ent")
# Out:
# Entity:  vos-pablo@interior.es CONTACT_INFO None
# D:\prog\Python_stuff\Lib\site-packages\spacy\glossary.py:20: UserWarning: [W118] Term 'CONTACT_INFO' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vos-pablo@interior.es
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CONTACT_INFO</span>
# </mark>
# </div></span>

# %%
relevant_labels = {'PERSON', 'GPE', 'DATE', 'ORG', 'PERCENT', 'CONTACT_INFO'}
met, stat = test_performance(df, relevant_labels)
print(f'avg precision: {np.average(met['prec'])}, recall: {np.average(met['rec'])}, F1: {np.average(met['F1'])}')
print(stat)
# Out:
# avg precision: 0.3103448275862069, recall: 0.5, F1: 0.3829787234042554
# {'DATE': 62688, 'GPE': 24954, 'PERSON': 47660, 'ORG': 37045, 'CONTACT_INFO': 7720, 'PERCENT': 11669}

# %% [markdown]
# Судя по статистике, удалось дополнительно правильно распознать 7720 сущностей

# %%
patterns = [{"label": "CONTACT_INFO", "pattern": [{'IS_LOWER': True, 'LIKE_EMAIL': True}]}]

ruler.add_patterns(patterns)

doc = nlp("vos-pablo@interior.es")

for ent in doc.ents:
    print('Entity: ', ent.text, ent.label_)

displacy.render(doc, style="ent")

# %% [markdown]
# Для определения остальных сущностей при rule-based подходе пришлось бы написать большое количество сложных правил.
# По всей видимости, для этого датасета лучше бы подошел подход с нейросетями
